# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Out:
# --2019-08-30 07:10:19--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.23.2.88, 52.86.84.98, 52.204.136.9, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.23.2.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13607069 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  12.98M  14.3MB/s    in 0.9s
#
# 2019-08-30 07:10:21 (14.3 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13607069/13607069]

# %%
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
# !./ngrok http 5000
# Out:
# 7=ngrok by @inconshreveable                                       (Ctrl+C to quit)                                                                                Session Status                connecting                                        Version                       2.3.34                                            Region                        United States (us)                                Web Interface                 http://127.0.0.1:4040                                                                                                             Connections                   ttl     opn     rt1     rt5     p50     p90                                     0       0       0.00    0.00    0.00    0.00                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Session Status                online    SsExpires7 hours, 59 minutesVrsion2.3.34            Rgio       United States (us)   Web Interface                 http://127.0.0.1:4040Frwardng htps://75b03121.ngrok.io ->htt://localhost:5000                                                                              Connections                   ttl     opn     rt1     rt5     p50     p90                                   0       0       0.00    0.00    0.00    0.00    :/75b03121.ngrok.io -> htp:/localhost:50 Forwarding                    https://75b03121.ngrok.io -> http://localhost:5000                                                                              Connectionsttlopnrt1 rt5 p5 p9                               0       0       0.00    0.00    0.00    0.00    1HTTP Requests-------------GET/2404 NOT FOUND11442robots.txt             GET/404 NOT FOUND404 NOT FOUND207101favicon.ico             robots.txtGET/404 NOT FOUND404 NOT FOUND304851431POST /webhok/                /favicon.ico /robots.txtGET/404 NOT FOUND200 OK407141      POSTwebhok/   200 OK       favicon.icorobots.txtGET/404 NOT FOUND200 OK501054731      POSTwebhok/   200 OK       favicon.icorobots.txtGET/404 NOT FOUND200 OK604231621504321004981      POSTwebhok/   200 OK       favicon.icorobots.txtGET/404 NOT FOUND500 INTERNAL SERVER ERROR7015211                         500 INTERNAL SERVER ERRORPOSTwebhok/   200 OK       favicon.icorobots.txtGET/404 NOT FOUND200 OK80037216050432103987654321029876543210198765432109 minutes 8765431      200 OK                   500 INTERNAL SERVER ERRORPOSTwebhok/   200 OK       favicon.icorobots.txt200 OK9021      200 OK                   500 INTERNAL SERVER ERRORPOSTwebhok/   200 OK       favicon.ico200 OK1008311      200 OK                   500 INTERNAL SERVER ERRORPOSTwebhok/   200 OK
# 200 OK1074231      200 OK                   500 INTERNAL SERVER ERROR200 OK200941      200 OK                   500 INTERNAL SERVER ERROR200 OK3010261      200 OK                   500 INTERNAL SERVER ERROR200 OK40094721      200 OK                   200 OK5031      200 OK6021009871 651      200 OK701006541      200 OK80191                200 OK9086354326, 59 minutes21807165432010498765432103987654321029876543210198765432109 minutes 87654321           5, 59 minutes876543210498765432103987654321029876543210198765432109 minutes 87654321           4, 59 minutes876543210498765432103987654321029876543210198765432109 minutes 871      200 OK2002921      200 OK1036311      200 OK205436215040321           3, 59 minutes876543210498765432103987654321029876543210198765432109 minutes 8654321           2, 59 minutes87654321049876543210398765432102987654321019876
